# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# prompt: import csv file to use

import pandas as pd

# Change the path to point to the CSV file on your Google Drive
doc_df = pd.read_csv('/content/drive/My Drive/doc_table.csv')

# Print the DataFrame
doc_df
# Out:
#     Doctor Name                       Specialty Telephone No. Hospital Name  \
# 0         Doc 1                Otolaryngologist      555-9684   Hospital 17
# 1         Doc 2   Infectious Disease Specialist      555-8167   Hospital 41
# 2         Doc 3                    Cardiologist      555-3822   Hospital 76
# 3         Doc 4              Gastroenterologist      555-2668   Hospital 87
# 4         Doc 5   Infectious Disease Specialist      555-7515   Hospital 64
# ..          ...                             ...           ...           ...
# 495     Doc 496   Infectious Disease Specialist      555-5997   Hospital 99
# 496     Doc 497                   Pulmonologist      555-4119   Hospital 91
# 497     Doc 498                      Oncologist      555-6163   Hospital 38
# 498     Doc 499                    Gynecologist      555-3123   Hospital 14
# 499     Doc 500                 General Surgeon      555-8898   Hospital 48
#
#      Longitude   Latitude
# 0    28.615475  77.167870
# ...

# %%
import numpy as np
import pandas as pd

# Set random seed for reproducibility
np.random.seed(42)

# Generate random ratings for doctors according to different patients
num_doctors = 500
num_patients = 1000

# Generate doctor names
doctor_names = doc_df['Doctor Name']
patient_ids = [f"Patient_{i}" for i in range(1, num_patients + 1)]


# Generate random ratings matrix
ratings_matrix = np.random.choice([0, 1, 2, 3, 4, 5], size=(num_patients, num_doctors))

# Create DataFrame
ratings_df = pd.DataFrame(ratings_matrix, columns=doctor_names, index=patient_ids)

ratings_df
# Out:
# Doctor Name   Doc 1  Doc 2  Doc 3  Doc 4  Doc 5  Doc 6  Doc 7  Doc 8  Doc 9  \
# Patient_1         3      4      2      4      4      1      2      2      2
# Patient_2         0      5      5      4      1      1      5      4      3
# Patient_3         5      4      5      5      3      5      2      5      5
# Patient_4         5      1      3      2      4      3      2      2      0
# Patient_5         2      5      3      4      4      4      2      3      1
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# Patient_996       4      5      4      2      2      1      3      5      5
# Patient_997       1      5      5      0      4      1      2      5      3
# Patient_998       3      2      4      0      4      3      3      0      4
# Patient_999       3      0      2      4      2      2      2      4      1
# Patient_1000      0      2      5      3      5      4      4      2      1
#
# ...

# %%
ratings_df.to_csv('rating.csv', index=False)
import os
os.getcwd()
# Out:
# '/content'

# %%
from google.colab import files
files.download('rating.csv')
